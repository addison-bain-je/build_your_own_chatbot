# %% [markdown]
# ### Install the libraries and app

# %% [markdown]
#  Install the required libraries and app necessary for unstructured

# %% [markdown]
# https://www.unstructured.io/

# %%
# Install Requirements
# !apt-get -qq install poppler-utils tesseract-ocr
# Upgrade Pillow to latest version
# %pip install -q --user --upgrade pillow
# Install Python Packages
# %pip install -q unstructured["local-inference"]==0.5.2 layoutparser
# %pip install -q "detectron2@git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2"
# Out:
# Selecting previously unselected package poppler-utils.
# (Reading database ... 122518 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.86.1-0ubuntu1.1_amd64.deb ...
# Unpacking poppler-utils (0.86.1-0ubuntu1.1) ...
# Selecting previously unselected package tesseract-ocr-eng.
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2build2_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2build2) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1) ...
# Setting up poppler-utils (0.86.1-0ubuntu1.1) ...
# ...

# %% [markdown]
# Install the required libaries

# %%
# Install the required libaries

# !pip install -q langchain transformers sentence_transformers openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.7/520.7 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 62.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 4.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# Install the vector database

# %%
# Install the vector database

# !pip install -q chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 2.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 28.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.8/927.8 kB 31.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 81.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 76.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 kB 38.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Import the necessary libaries

# %%
import os
import pandas as pd

from langchain.document_loaders import UnstructuredPDFLoader
from langchain.llms import HuggingFaceHub,OpenAI
from langchain.embeddings import HuggingFaceEmbeddings,OpenAIEmbeddings

from langchain.vectorstores import Chroma

from langchain.text_splitter import RecursiveCharacterTextSplitter

from langchain.chains.question_answering import load_qa_chain

# %%
#@title Set the API keys 
with open('keys.txt') as f:
    lines = f.readlines()

hf_api = lines[0][12:-1]

# %%
os.environ['HUGGINGFACEHUB_API_TOKEN'] = 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

# %% [markdown]
# ### Initialise the HuggingFace Model & the HuggingFace Embedding

# %%
model = 'bigscience/bloomz' #@param {type:"string"}

hf_llm = HuggingFaceHub(repo_id=model,model_kwargs={'temperature':1e-10,"max_length":200})

# %%
query = "Who is the prime minister of Singapore?"
hf_llm(query)
# Out:
# ' Lee Hsien Loong'

# %% [markdown]
# ### Load the Documents

# %%
simple_loader = UnstructuredPDFLoader("/content/Toothpaste_solution.pdf")

# %%
onepage_data = simple_loader.load()

# %%
print(f" The number of documents : {len(onepage_data)}")
print(f" The number of words in the document/s : {len(onepage_data[0].page_content.split())}")
print(f" The number of tokens count : {hf_llm.get_num_tokens(onepage_data[0].page_content)}")
# Out:
#  The number of documents : 1
#  The number of words in the document/s : 318
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ...
#  The number of tokens count : 399

# %% [markdown]
# https://python.langchain.com/en/latest/use_cases/question_answering.html

# %%
def simple_qa_chain(query:str,input_docs:list,llm:HuggingFaceHub,verbose=False):
  """
  Return answer to the query
  """
  
  qa_chain = load_qa_chain(llm, chain_type="stuff",verbose=verbose)

  return qa_chain.run(input_documents=input_docs, question=query)

# %%
query = "What was the situation they were facing?"

simple_qa_chain(query,onepage_data,hf_llm)
# Out:
# ' They were shipping empty boxes'

# %%
query = "What impact did the situation have on the reputation of the company in the market?"

simple_qa_chain(query,onepage_data,hf_llm)
# Out:
# ' They were perceived as a company that could not be trusted.'

# %%
query = "What did the company do to resolve it?"

simple_qa_chain(query,onepage_data,hf_llm)
# Out:
# ' They hired an external engineering company'

# %%
query = "How much did the company spend to solve the issue"

simple_qa_chain(query,onepage_data,hf_llm)
# Out:
# ' $8 million'

# %%
query = "Was there discovered solution that resolved the issue"

simple_qa_chain(query,onepage_data,hf_llm)
# Out:
# ' Yes'

# %%
query = "What is the discoverd solution"

simple_qa_chain(query,onepage_data,hf_llm)
# Out:
# ' A $20 desk fan'

# %%
query = "What was the cheaper solution that was discovered that resolved the issue"

simple_qa_chain(query,onepage_data,hf_llm)
# Out:
# ' A $20 desk fan'

# %% [markdown]
# ### Limitation of Tokens

# %% [markdown]
# Source Document:
#
# https://www.iras.gov.sg/media/docs/default-source/e-tax/etaxguide_2023-gst-rate-change---a-guide-for-gst-registered-businesses_1st-edition.pdf?sfvrsn=5224b08a_32#:~:text=According%20to%20the%20general%20rule,delivered%20before%201%20Jan%202023.

# %%
# !wget https://www.iras.gov.sg/media/docs/default-source/e-tax/etaxguide_2023-gst-rate-change---a-guide-for-gst-registered-businesses_1st-edition.pdf
# Out:
# --2023-04-13 01:16:07--  https://www.iras.gov.sg/media/docs/default-source/e-tax/etaxguide_2023-gst-rate-change---a-guide-for-gst-registered-businesses_1st-edition.pdf
# Resolving www.iras.gov.sg (www.iras.gov.sg)... 104.16.213.134
# Connecting to www.iras.gov.sg (www.iras.gov.sg)|104.16.213.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 820405 (801K) [application/pdf]
# Saving to: ‘etaxguide_2023-gst-rate-change---a-guide-for-gst-registered-businesses_1st-edition.pdf’
#
# etaxguide_2023-gst- 100%[===================>] 801.18K  --.-KB/s    in 0.02s
#
# 2023-04-13 01:16:07 (45.9 MB/s) - ‘etaxguide_2023-gst-rate-change---a-guide-for-gst-registered-businesses_1st-edition.pdf’ saved [820405/820405]

# %%
loader = UnstructuredPDFLoader("/content/etaxguide_2023-gst-rate-change---a-guide-for-gst-registered-businesses_1st-edition.pdf")

# %%
data = loader.load()

# %% [markdown]
# You can think of tokens as pieces of words used for natural language processing. For English text, 1 token is approximately 4 characters or 0.75 words.
#
# https://openai.com/pricing

# %%
print(f" The number of documents : {len(data)}")
print(f" The number of words in the document/s : {len(data[0].page_content.split())}")
print(f" The number of tokens count (approx) : {hf_llm.get_num_tokens(data[0].page_content)}")
# Out:
#  The number of documents : 1
#  The number of words in the document/s : 16141
# Token indices sequence length is longer than the specified maximum sequence length for this model (20796 > 1024). Running this sequence through the model will result in indexing errors
#  The number of tokens count (approx) : 20796

# %%
query = "By when must we issued credit note for value of services performed before 1 Jan 2023 if you elected to change the GST to 7%"

simple_qa_chain(query,data,hf_llm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-78c828fcec04> in <cell line: 3>()
#       1 query = "By when must we issued credit note for value of services performed before 1 Jan 2023 if you elected to change the GST to 7%"
#       2
# ----> 3 simple_qa_chain(query,data,hf_llm)
#
# <ipython-input-15-59aa2e832fa4> in simple_qa_chain(query, input_docs, llm, verbose)
#       6   qa_chain = load_qa_chain(llm, chain_type="stuff",verbose=verbose)
#       7
# ----> 8   return qa_chain.run(input_documents=input_docs, question=query)
#
# /usr/local/lib/python3.9/dist-packages/langchain/chains/base.py in run(self, *args, **kwargs)
#     214
#     215         if kwargs and not args:
# --> 216             return self(kwargs)[self.output_keys[0]]
#     217
#     218         raise ValueError(
#
# ...
